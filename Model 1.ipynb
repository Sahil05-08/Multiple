# %%
import pandas as ds

# %%
c=ds.read_csv("BostonHousing.csv")
c
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
c.rename(columns={'medv':'Price'})
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  Price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
c.shape
# Out:
# (506, 14)

# %%
c.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
c.info()#use to check the the data info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
c.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# crim     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# zn       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# indus    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# chas     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# nox      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# rm       501.0    6.284341    0.705587    3.56100    5.884000    6.20800
# age      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# dis      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# rad      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# tax      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# ptratio  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# b        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
c.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
import seaborn as sns
sns.heatmap(c.corr(),annot=True)
# Out:
# <Axes: >

# %%
c.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
c.shape
# Out:
# (501, 14)

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     501 non-null    float64
#  1   zn       501 non-null    float64
#  2   indus    501 non-null    float64
#  3   chas     501 non-null    int64
#  4   nox      501 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      501 non-null    float64
#  7   dis      501 non-null    float64
#  8   rad      501 non-null    int64
#  9   tax      501 non-null    int64
#  10  ptratio  501 non-null    float64
#  11  b        501 non-null    float64
#  12  lstat    501 non-null    float64
#  13  medv     501 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 58.7 KB

# %%
x=c.iloc[:,:-1]
y=c.iloc[:,-1]
x
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 501, dtype: float64

# %%
x.shape
# Out:
# (501, 13)

# %%
y.shape
# Out:
# (501,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train_scaled=scaler.fit_transform(x_train)
x_train_scaled
# Out:
# array([[-0.49097342,  0.58205708, -0.86103483, ...,  0.55425293,
#          0.22108052,  0.267957  ],
#        [-0.51284705, -0.47096977, -1.13251055, ..., -0.72310786,
#          0.10955865, -0.491199  ],
#        [ 0.80829834, -0.47096977,  1.0019494 , ...,  0.78235307,
#          0.39721706,  1.04555977],
#        ...,
#        [-0.50830672, -0.47096977,  2.08641593, ...,  0.28053276,
#          0.21627253,  0.24383428],
#        [-0.48264803, -0.47096977, -0.60535927, ..., -0.26690758,
#          0.4417789 ,  0.51769803],
#        [-0.51132091, -0.47096977, -1.01616381, ..., -0.85996794,
#          0.42653406, -0.88851428]], shape=(375, 13))

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train_scaled,y_train)
# Out:
# 0.7878670945030953

# %%
x_test_scaled=scaler.transform(x_test)

# %%
y_pred=model.predict(x_test_scaled)

# %%
y_pred
# Out:
# array([28.87168816, 34.32381972, 27.77011358, 18.64783986, 29.12474146,
#        20.59828897,  1.45963299, 44.78937391, 24.32647345, 27.66154768,
#        20.36136961, 22.50359076, 26.27519308, 11.37892659, 25.41673288,
#        29.39525649, 14.03635905, 17.33127196, 25.82570312, 31.22591939,
#        20.81017056, 21.54497736, 13.56998423, 20.09349989, 18.78705836,
#        15.25692902, 16.37404196, 17.02010396, 24.26527595, 28.86726157,
#        12.20913971, 20.9820701 , 19.21999595, 37.25640523, 23.03322592,
#         8.03019789, 18.57686266, 15.07568366, 31.08730674, 28.00956828,
#        18.66546842, 10.55237553, 15.23796788, 37.67718244, 22.24083688,
#        25.09788081, 23.36555776, 20.831419  , 12.77586916, 16.61870187,
#        27.99248984, 30.74241227, 35.40272183, 16.05252713, 19.5809096 ,
#        19.15785191, 22.01831064, 31.11057444, 30.99339787, 34.80545179,
#        26.59663264, 17.6826433 , 15.1882621 , 18.46610783, 31.7510098 ,
# ...

# %%
y_test
# Out:
# 93     25.0
# 259    30.1
# 289    24.8
# 451    15.2
# 344    31.2
#        ...
# 51     20.5
# 139    17.8
# 371    50.0
# 404     8.5
# 244    17.6
# Name: medv, Length: 126, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.553594864689833

# %%
from sklearn.linear_model import Ridge,Lasso,ElasticNet

# %%
ridge=Ridge()

# %%
ridge.fit(x_train_scaled,y_train)
# Out:
# Ridge()

# %%
ridge.score(x_train_scaled,y_train)
# Out:
# 0.7878548417970046

# %%
y_pred=ridge.predict(x_test_scaled)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5525770519679578

# %%
lasso=Lasso()

# %%
lasso.fit(x_train_scaled,y_train)
# Out:
# Lasso()

# %%
y_pred=lasso.predict(x_test_scaled)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4967312572719744

# %%
e=ElasticNet()
e.fit(x_train_scaled,y_train)
# Out:
# ElasticNet()

# %%
y_pred=e.predict(x_test_scaled)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.47027106863960955

# %%
c.loc[3]
# Out:
# crim         0.03237
# zn           0.00000
# indus        2.18000
# chas         0.00000
# nox          0.45800
# rm           6.99800
# age         45.80000
# dis          6.06220
# rad          3.00000
# tax        222.00000
# ptratio     18.70000
# b          394.63000
# lstat        2.94000
# medv        33.40000
# Name: 3, dtype: float64

# %%
data=[[0.0327,0.0000,2.18000,0.00000,0.45800,6.99800,45.80000,6.06220,3.00000,222.00000,18.70000,394.63000,2.94000]]
sc_scaled=scaler.transform(data)
sc_scaled
# Out:
# C:\Users\Sahil Suryavanshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.51505399, -0.47096977, -1.28476678, -0.26726124, -0.84095884,
#          0.98322563, -0.79919559,  1.08719811, -0.73211339, -1.09495084,
#          0.09805265,  0.41515907, -1.36387364]])

# %%
model.predict(sc_scaled)
# Out:
# array([29.2357792])

# %%
import joblib 
joblib.dump(model,"model.joblib")
# Out:
# ['model.joblib']

# %%
joblib.dump(scaler,"scaled.joblib")
# Out:
# ['scaled.joblib']

# %%
joblib_model=joblib.load("model.joblib")
joblib_scaled=joblib.load("scaled.joblib")

# %%
data1=[[0.0327,0.0000,2.18000,0.00000,0.45800,6.99800,45.80000,6.06220,3.00000,222.00000,18.70000,394.63000,2.94000]]
c=joblib_scaled.transform(data1)
c
# Out:
# C:\Users\Sahil Suryavanshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.51505399, -0.47096977, -1.28476678, -0.26726124, -0.84095884,
#          0.98322563, -0.79919559,  1.08719811, -0.73211339, -1.09495084,
#          0.09805265,  0.41515907, -1.36387364]])

# %%
joblib_model.predict(c)
# Out:
# array([29.2357792])

# %%
d=c.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 d=c.columns
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
